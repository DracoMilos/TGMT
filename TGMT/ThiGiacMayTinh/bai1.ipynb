# %%
# Dùng để ghi nhớ 
# Shift + Enter => Run Code thêm dòng mới

# %%
# %pip install Pillow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Thêm thư viện
from PIL import Image

# %%
# Khai báo 1 biến chứa thư mục ( / hoặc \ )
dir = "C:/Users/admin/OneDrive - Dong Nai Technology University (DNTU)/TGMT/ThuVien"

# %%
# Đường dẫn tới hình ảnh 
image_path = dir + '/images1.jpg'
print (image_path)
# Out:
# C:/Users/admin/OneDrive - Dong Nai Technology University (DNTU)/TGMT/ThuVien/images1.jpg

# %%
# Sử dụng Image.open() đọc ảnh 
imgTGMT = Image.open(image_path)

# %%
#Display image.
#Display (imgTGMT)
#Image Information.
print("Định dạng ảnh:",imgTGMT.format)
print("Kích thước ảnh:",imgTGMT.size)
# Out:
# Định dạng ảnh: JPEG
# Kích thước ảnh: (318, 159)

# %%
new_img_01_path = dir + "/images1.jpg"
new_img_PNG_01_path = dir + "/images1.PNG"
imgTGMT.save(new_img_01_path)
imgTGMT.save(new_img_PNG_01_path)

# %%
display(imgTGMT)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=318x159>

# %%
imgTGMT.close()
