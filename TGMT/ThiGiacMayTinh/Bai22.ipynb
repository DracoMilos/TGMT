# %%
import cv2
import time

# %%
# Đọc video từ file
my_video = cv2.VideoCapture('C:/Users/admin/OneDrive - Dong Nai Technology University (DNTU)/TGMT/ThuVien/Video.mp4')

# %%
# Tạo cửa sổ để hiển thị
cv2.namedWindow('Video Player', cv2.WINDOW_NORMAL)

# %%
# Ghi text trên hình ảnh
font = cv2.FONT_HERSHEY_SIMPLEX
font_color = (255, 255, 255)
font_scale = 2
font_thicknes = 2

# %%
# Hiển thị từng khung ảnh
while True:
    # Thời gian trước khi đọc
    start_time = time.time()
    # Đọc 1 frame
    ret, frame = my_video.read()
    # Thoát khi không thể đọc được frame
    if not ret:
        break
    # Thời gian trước khi đọc
    end_time = time.time()    
    # Tình FPS:
    fps = 1/(end_time-start_time)
    # Ghi số lượng fps
    cv2.putText(frame, f'FPS: {fps:.2f}', (100, 100), font, font_scale, font_color , font_thicknes)
    # Hiển thị
    cv2.imshow('Video Player', frame)
    if(cv2.waitKey(10)==ord('q')):
        break

# Hủy bỏ player
my_video.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[11], line 13
#      11 end_time = time.time()
#      12 # Tình FPS:
# ---> 13 fps = 1/(end_time-start_time)
#      14 # Ghi số lượng fps
#      15 cv2.putText(frame, f'FPS: {fps:.2f}', (100, 100), font, font_scale, font_color , font_thicknes)
#
# ZeroDivisionError: float division by zero
