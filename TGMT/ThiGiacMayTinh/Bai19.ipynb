# %%
# !pip install opencv-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/38.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/38.8 MB 330.3 kB/s eta 0:01:58
#    ---------------------------------------- 0.1/38.8 MB 1.1 MB/s eta 0:00:37
#    ---------------------------------------- 0.2/38.8 MB 1.8 MB/s eta 0:00:22
#    ---------------------------------------- 0.4/38.8 MB 2.0 MB/s eta 0:00:20
#     --------------------------------------- 0.6/38.8 MB 2.8 MB/s eta 0:00:14
#     --------------------------------------- 0.8/38.8 MB 3.1 MB/s eta 0:00:13
#    - -------------------------------------- 1.1/38.8 MB 3.3 MB/s eta 0:00:12
#    - -------------------------------------- 1.3/38.8 MB 3.6 MB/s eta 0:00:11
#    - -------------------------------------- 1.5/38.8 MB 3.7 MB/s eta 0:00:11
#    - -------------------------------------- 1.7/38.8 MB 3.8 MB/s eta 0:00:10
# ...

# %%
#import thu vien 
import cv2

# %%
def display(title, img):
    cv2.imshow(title, img)
    #Cho mot khoang thoi gian
    cv2.waitKey(0)
    #dong window
    cv2.destroyWindow(title)

# %%
#doc mot anh( Nhan Tab de nhin autocomplete)
path='C:/Users/admin/OneDrive - Dong Nai Technology University (DNTU)/TGMT/ThuVien/images4.jpg'
img = cv2.imread(path)
#in thong tin cua anh
print(img)
# Out:
# [[[ 61 170 238]
#   [ 67 176 244]
#   [ 69 178 246]
#   ...
#   [ 60 155 218]
#   [ 61 152 219]
#   [ 60 151 218]]
#
#  [[ 74 183 251]
#   [ 67 176 244]
#   [ 75 184 252]
#   ...
#   [ 61 156 219]
#   [ 62 153 220]
#   [ 60 151 218]]
#
#  [[ 62 171 239]
#   [ 68 177 245]
#   [ 75 184 252]
#   ...
#   [ 62 157 220]
#   [ 61 155 221]
#   [ 60 154 220]]
#
#  ...
#
#  [[ 54 153 205]
#   [ 54 153 205]
#   [ 56 152 205]
#   ...
#   [177  92 112]
#   [155  62  83]
#   [160  63  83]]
#
#  [[ 58 153 203]
#   [ 60 153 202]
#   [ 61 152 203]
#   ...
#   [151  63  87]
#   [168  77 102]
#   [157  66  91]]
#
#  [[ 63 152 202]
#   [ 63 153 200]
#   [ 65 152 202]
#   ...
#   [146  67  94]
#   [165  90 118]
#   [145  71  99]]]

# %%
# Lấy kích thước
print(img.shape)
x, y, z = img.shape
print(x)
print(y)
print(z)
# Out:
# (159, 318, 3)
# 159
# 318
# 3

# %%
# Tách màu
b, g, r = cv2.split(img)
cv2.imshow('Window', img)
cv2.imshow('Red', r)
cv2.imshow('Green', g)
cv2.imshow('Blue', b)

# Chờ một khoảng thời gian
cv2.waitKey(0)
# Đóng window
cv2.destroyAllWindows()

# %%
gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
img_2 = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
cv2.imshow('Window', img)
cv2.imshow('gray_img', gray_img)
cv2.imshow('img_2', img_2)
# Chờ một khoảng thời gian
cv2.waitKey(0)
# Đóng window
cv2.destroyAllWindows()

# %%
# Thay đổi thông số của điểm ảnh
height, width, z = img.shape
quater_h = height/2
quater_w = width/2

# geen color
green_color = (0,255,0)

# copy ảnh
img2 = img.copy()

# thay đổi màu của góc 1/4 bên trái trên

for y in range(int(quater_h)):
    for x in range(int(quater_w)):
        img2[y, x] = green_color
# Hiển thị
display('Window', img)
display('Window-2', img2)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[10], line 18
#      16         img2[y, x] = green_color
#      17 # Hiển thị
# ---> 18 display('Window', img)
#      19 display('Window-2', img2)
#
# Cell In[3], line 6, in display(title, img)
#       4 cv2.waitKey(0)
#       5 #dong window
# ----> 6 cv2.destroyWindow(title)
#
# error: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\highgui\src\window_w32.cpp:1261: error: (-27:Null pointer) NULL window: 'Window' in function 'cvDestroyWindow'
